# %%
from ucimlrepo import list_available_datasets
from ucimlrepo import fetch_ucirepo

import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import seaborn as sns
import statistics as stats
import scipy.stats as stats

# %%
dataset_name = "Appliances Energy Prediction"

# %%
dataset = fetch_ucirepo(name=dataset_name)

# %%
dataset.data.features
# Out:
#                      date  lights         T1       RH_1         T2       RH_2  \
# 0      2016-01-1117:00:00      30  19.890000  47.596667  19.200000  44.790000
# 1      2016-01-1117:10:00      30  19.890000  46.693333  19.200000  44.722500
# 2      2016-01-1117:20:00      30  19.890000  46.300000  19.200000  44.626667
# 3      2016-01-1117:30:00      40  19.890000  46.066667  19.200000  44.590000
# 4      2016-01-1117:40:00      40  19.890000  46.333333  19.200000  44.530000
# ...                   ...     ...        ...        ...        ...        ...
# 19730  2016-05-2717:20:00       0  25.566667  46.560000  25.890000  42.025714
# 19731  2016-05-2717:30:00       0  25.500000  46.500000  25.754000  42.080000
# 19732  2016-05-2717:40:00      10  25.500000  46.596667  25.628571  42.768571
# 19733  2016-05-2717:50:00      10  25.500000  46.990000  25.414000  43.036000
# 19734  2016-05-2718:00:00      10  25.500000  46.600000  25.264286  42.971429
#
# ...

# %%
# Convert features and target to DataFrame
df = pd.concat([dataset.data.features, dataset.data.targets], axis=1)

# %% [markdown]
# # Check Missing Values

# %%
df.isnull().sum()
# Out:
# date           0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# Appliances     0
# dtype: int64

# %%
df.set_index('date', inplace=True)

# %%
df.head()
# Out:
#                     lights     T1       RH_1    T2       RH_2     T3  \
# date
# 2016-01-1117:00:00      30  19.89  47.596667  19.2  44.790000  19.79
# 2016-01-1117:10:00      30  19.89  46.693333  19.2  44.722500  19.79
# 2016-01-1117:20:00      30  19.89  46.300000  19.2  44.626667  19.79
# 2016-01-1117:30:00      40  19.89  46.066667  19.2  44.590000  19.79
# 2016-01-1117:40:00      40  19.89  46.333333  19.2  44.530000  19.79
#
#                          RH_3         T4       RH_4         T5  ...   RH_9  \
# date                                                            ...
# 2016-01-1117:00:00  44.730000  19.000000  45.566667  17.166667  ...  45.53
# 2016-01-1117:10:00  44.790000  19.000000  45.992500  17.166667  ...  45.56
# 2016-01-1117:20:00  44.933333  18.926667  45.890000  17.166667  ...  45.50
# 2016-01-1117:30:00  45.000000  18.890000  45.723333  17.166667  ...  45.40
# 2016-01-1117:40:00  45.000000  18.890000  45.530000  17.200000  ...  45.40
#
# ...

# %% [markdown]
# # Explorative Data Analysis (EDA)

# %%
df.describe().T
# Out:
#                count        mean         std         min         25%  \
# lights       19735.0    3.801875    7.935988    0.000000    0.000000
# T1           19735.0   21.686571    1.606066   16.790000   20.760000
# RH_1         19735.0   40.259739    3.979299   27.023333   37.333333
# T2           19735.0   20.341219    2.192974   16.100000   18.790000
# RH_2         19735.0   40.420420    4.069813   20.463333   37.900000
# T3           19735.0   22.267611    2.006111   17.200000   20.790000
# RH_3         19735.0   39.242500    3.254576   28.766667   36.900000
# T4           19735.0   20.855335    2.042884   15.100000   19.530000
# RH_4         19735.0   39.026904    4.341321   27.660000   35.530000
# T5           19735.0   19.592106    1.844623   15.330000   18.277500
# RH_5         19735.0   50.949283    9.022034   29.815000   45.400000
# T6           19735.0    7.910939    6.090347   -6.065000    3.626667
# RH_6         19735.0   54.609083   31.149806    1.000000   30.025000
# ...

# %% [markdown]
# # Histogram to understand the distribution

# %%
selected_columns = ['T1', 'RH_1', 'T2', 'RH_2']  # change to your desired columns

for col in selected_columns:
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
# Boxplot to identify outliers 
selected_columns = ['T1', 'RH_1', 'T2', 'RH_2'] 
for i in selected_columns:
    sns.boxplot(data=df, x=i)
    plt.show()

# %%
# Scatter plot to understand the relationships between target feature and features independents
selected_columns = ['T1', 'RH_1', 'T2', 'RH_2']
for i in selected_columns:
    sns.scatterplot(data=df, x=i, y='Appliances')
    plt.show()

# %%
df.corr()
# Out:
#                lights        T1      RH_1        T2      RH_2        T3  \
# lights       1.000000 -0.023528  0.106968 -0.005622  0.050985 -0.097393
# T1          -0.023528  1.000000  0.164006  0.836834 -0.002509  0.892402
# RH_1         0.106968  0.164006  1.000000  0.269839  0.797535  0.253230
# T2          -0.005622  0.836834  0.269839  1.000000 -0.165610  0.735245
# RH_2         0.050985 -0.002509  0.797535 -0.165610  1.000000  0.137319
# T3          -0.097393  0.892402  0.253230  0.735245  0.137319  1.000000
# RH_3         0.131161 -0.028550  0.844677  0.121497  0.678326 -0.011234
# T4          -0.008859  0.877001  0.106180  0.762066 -0.047304  0.852778
# RH_4         0.114936  0.097861  0.880359  0.231563  0.721435  0.122737
# T5          -0.078745  0.885247  0.205797  0.720550  0.110409  0.888169
# RH_5         0.141233 -0.014782  0.303258  0.029595  0.250271 -0.066355
# T6          -0.079029  0.654769  0.316141  0.801186 -0.009670  0.686882
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# # Outlier Treatments

# %%
# Whether to do outlier treatment or not if we do ?
def  wiskers(col):
    q1, q3 = np.percentile(col, [25,75])
    iqr = q3 - q1 
    lw = q1 - 1.5*iqr
    upw = q3 + 1.5*iqr
    return lw, upw

# %%
df.head()
# Out:
#                     lights     T1       RH_1    T2       RH_2     T3  \
# date
# 2016-01-1117:00:00      30  19.89  47.596667  19.2  44.790000  19.79
# 2016-01-1117:10:00      30  19.89  46.693333  19.2  44.722500  19.79
# 2016-01-1117:20:00      30  19.89  46.300000  19.2  44.626667  19.79
# 2016-01-1117:30:00      40  19.89  46.066667  19.2  44.590000  19.79
# 2016-01-1117:40:00      40  19.89  46.333333  19.2  44.530000  19.79
#
#                          RH_3         T4       RH_4         T5  ...   RH_9  \
# date                                                            ...
# 2016-01-1117:00:00  44.730000  19.000000  45.566667  17.166667  ...  45.53
# 2016-01-1117:10:00  44.790000  19.000000  45.992500  17.166667  ...  45.56
# 2016-01-1117:20:00  44.933333  18.926667  45.890000  17.166667  ...  45.50
# 2016-01-1117:30:00  45.000000  18.890000  45.723333  17.166667  ...  45.40
# 2016-01-1117:40:00  45.000000  18.890000  45.530000  17.200000  ...  45.40
#
# ...

# %%
for i in ['Visibility', 'Tdewpoint', 'Windspeed']:
    lw, upw = wiskers(df[i])
    df[i] = np.where(df[i] < lw, lw, df[i])
    df[i] = np.where(df[i] > upw, upw, df[i])

# %%
for i in ['Visibility', 'Tdewpoint', 'Windspeed']:
    sns.boxplot(df[i])
    plt.show()

# %%
df.head()
# Out:
#                     lights     T1       RH_1    T2       RH_2     T3  \
# date
# 2016-01-1117:00:00      30  19.89  47.596667  19.2  44.790000  19.79
# 2016-01-1117:10:00      30  19.89  46.693333  19.2  44.722500  19.79
# 2016-01-1117:20:00      30  19.89  46.300000  19.2  44.626667  19.79
# 2016-01-1117:30:00      40  19.89  46.066667  19.2  44.590000  19.79
# 2016-01-1117:40:00      40  19.89  46.333333  19.2  44.530000  19.79
#
#                          RH_3         T4       RH_4         T5  ...   RH_9  \
# date                                                            ...
# 2016-01-1117:00:00  44.730000  19.000000  45.566667  17.166667  ...  45.53
# 2016-01-1117:10:00  44.790000  19.000000  45.992500  17.166667  ...  45.56
# 2016-01-1117:20:00  44.933333  18.926667  45.890000  17.166667  ...  45.50
# 2016-01-1117:30:00  45.000000  18.890000  45.723333  17.166667  ...  45.40
# 2016-01-1117:40:00  45.000000  18.890000  45.530000  17.200000  ...  45.40
#
# ...

# %%
for i in df.select_dtypes(include="object").columns:
    print(df[i].value_counts())
    print("***10")

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Summary of the dataset 
df.describe()
# Out:
#              lights            T1          RH_1            T2          RH_2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean       3.801875     21.686571     40.259739     20.341219     40.420420
# std        7.935988      1.606066      3.979299      2.192974      4.069813
# min        0.000000     16.790000     27.023333     16.100000     20.463333
# 25%        0.000000     20.760000     37.333333     18.790000     37.900000
# 50%        0.000000     21.600000     39.656667     20.000000     40.500000
# 75%        0.000000     22.600000     43.066667     21.500000     43.260000
# max       70.000000     26.260000     63.360000     29.856667     56.026667
#
#                  T3          RH_3            T4          RH_4            T5  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      22.267611     39.242500     20.855335     39.026904     19.592106
# ...

# %%
df.shape
# Out:
# (19735, 28)

# %% [markdown]
# # Discrete Variables and Continuous Variable

# %% [markdown]
# ### 1. PMF (Probability Mass Function)

# %%
light = df['lights'].value_counts(normalize=True)
light
# Out:
# lights
# 0     0.772840
# 10    0.112085
# 20    0.082290
# 30    0.028325
# 40    0.003902
# 50    0.000456
# 70    0.000051
# 60    0.000051
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=light.index, y=light.values)
plt.xlabel('Energy consumption of lights (in Wh)')
plt.ylabel("Probability")
plt.title("PMF of light Usage")
plt.show()

# %%
bins = range(0, df['Appliances'].max() + 50 + 50)

# %%
# Normalize to ensure sum of probability 
pmf, bin_edges = np.histogram(df['Appliances'], bins=bins, density=True)
pmf /=pmf.sum()

# %%
# Plot PMF with bins
plt.figure(figsize=(8, 5))
plt.bar(bin_edges[:-1], pmf, width=30, edgecolor="black", alpha=0.7)
plt.xlabel("Energy Consumption (Wh) - Binned")
plt.ylabel("Probability")
plt.title("PMF of Appliance Energy Consumption (Binned)")
plt.xticks(bin_edges, rotation=45)
plt.grid(True, linestyle="--", alpha=0.5)

plt.show()

# %% [markdown]
# ### Probability Density  Function for Continuous Variables

# %%
t1 = df['T1']

sns.kdeplot(t1, fill=True)
plt.xlabel('Temperature')
plt.ylabel('Density')
plt.title("PDF of Temperature T1")
plt.show()

# %%
sns.histplot(df["Windspeed"], bins=20, kde=True)
plt.title("Distribution of Windspeed")
plt.show()

# %%
stats.probplot(df["T1"], dist="norm", plot=plt)
plt.title("Q-Q Plot for Temperature (T1)")
plt.show()

# %%
df.hist(figsize=(12, 10), bins=30)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()
